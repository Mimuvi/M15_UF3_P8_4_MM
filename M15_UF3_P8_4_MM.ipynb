# %%
# plot photo with detected faces using opencv cascade classifier
from cv2 import imread
from cv2 import imshow
from cv2 import waitKey
from cv2 import destroyAllWindows
from cv2 import CascadeClassifier
from cv2 import rectangle
# face detection with mtcnn on a photograph
from matplotlib import pyplot
from matplotlib.patches import Rectangle
from matplotlib.patches import Circle

# %%
#Deteccion de las imagenes
from google.colab.patches import cv2_imshow

# %% [markdown]
# **Detección facial con aprendizaje profundo**
# 1. Detección de rostro
# 2. Fotografías de prueba
# 3. Detección de rostros con OpenCV
# 4. Detección de rostros con aprendizaje profundo
#
# ---
#
# Algoritmo de detección de rostros Classifier y la biblioteca que usa es OpenCV tiene interfaz phyton y programa C++.

# %%
# check opencv version Importar la biblioteca OpenCV
import cv2
# print version number Muestra por pantalla la version de la biblioteca.
print(cv2.__version__)
# Out:
# 4.1.2

# %% [markdown]
# Cargar el modelo pre-entrenado para detectar los rostros fronteles del proyecto OpenCV.
#
# CascadeClassifier: Es un clase que se utiliza para detectar objectos en una secuencia de video.

# %%
classifier = CascadeClassifier('haarcascade_frontalface_default.xml')

# %% [markdown]
# Cargar la imagen
#
# La función imread(filename) lee imagenes del archivo que se "especifica" entre parentesis y pixels es el nombre que se asigna a esta función.

# %%
# load the photograph
pixel = cv2.imread('test1.jpg')

# %% [markdown]
# Después de cargar la imagen con la funcion  detectMultiScale que se utiliza para detectar cara u ojos de la imagen (pixels). Mediante función hara que devuelva una lista de cuadro delimitador que tendrá cada rostro que se detecte en la imagen.
# Mostra por pantalla los cuadros delimitadores que tienen la imagen.

# %%
# perform face detection
bboxes = classifier.detectMultiScale(pixel)
# print bounding box for each detected face
for box in bboxes:
	print(box)
# Out:
# [173  74 108 108]
# [363 104  97  97]

# %% [markdown]
# La función rectagle()
#
# Se extraerá de la lista de caja las cordenadas X e Y de la p
# x,yanho,alto
#
#
# Se puede modificar el "trazo" de la imagen y dibujar cada  cuadro delimitador.

# %%
# extract
x, y, width, height = box
x2, y2 = x + width, y + height
# draw a rectangle over the pixels
rectangle(pixel, (x, y), (x2, y2), (0,0,255), 1)
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [232, 230, 230],
#         [232, 230, 230],
#         [232, 230, 230]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [232, 230, 230],
#         [232, 230, 230],
#         [232, 230, 230]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [232, 230, 230],
#         [232, 230, 230],
#         [232, 230, 230]],
#
#        ...,
#
#        [[112, 123, 145],
#         [124, 135, 157],
#         [133, 141, 164],
#         ...,
#         [ 97, 169, 241],
#         [ 98, 167, 240],
#         [ 96, 168, 240]],
#
#        [[146, 158, 186],
#         [151, 163, 191],
#         [148, 160, 188],
#         ...,
#         [ 99, 170, 238],
#         [ 99, 168, 238],
#         [ 98, 168, 238]],
#
#        [[143, 153, 183],
#         [145, 155, 185],
#         [139, 149, 179],
# ...

# %% [markdown]
# Muestra la imagen pixel por pantalla, con la función waitKey se enlaza con el teclado para mantener la ventana abierta hasta que presionemos una tecla y con la función destroyAllWindows cierra todas las ventanas creadas.
#
# ---
# ![ejemplo.PNG](data:image/png;base64,...)

# %%
# perform face detection
bboxes = classifier.detectMultiScale(pixel)
# print bounding box for each detected face
for box in bboxes:
	# extract
	x, y, width, height = box
	x2, y2 = x + width, y + height
	# draw a rectangle over the pixels
	rectangle(pixel, (x, y), (x2, y2), (0,0,255), 1)
# show the image
cv2_imshow(pixel)
# keep the window open until we press a key
cv2.waitKey(0)
# close the window
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=640x427 at 0x7F5152DFF6D0>

# %% [markdown]
# Resultado de la imagen pixel2 ('test2.jpg')

# %%
# load the photograph
pixel2 = imread('test2.jpg')
# perform face detection
bboxes = classifier.detectMultiScale(pixel2, 1.1, 3)
# print bounding box for each detected face
for box in bboxes:
	# extract
	x, y, width, height = box
	x2, y2 = x + width, y + height
	# draw a rectangle over the pixels
	rectangle(pixel2, (x, y), (x2, y2), (0,0,255), 1)
# show the image
cv2_imshow(pixel2)
# keep the window open until we press a key
cv2.waitKey(0)
# close the window
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=640x486 at 0x7F5152E18410>

# %%
# load the photograph
pixel2 = imread('test2.jpg')
# perform face detection
bboxes = classifier.detectMultiScale(pixel2, 1.05, 8)
# print bounding box for each detected face
for box in bboxes:
# extract
	x, y, width, height = box
	x2, y2 = x + width, y + height
# draw a rectangle over the pixels
	rectangle(pixel2, (x, y), (x2, y2), (0,0,255), 1)
# show the image
cv2_imshow(pixel2)
# keep the window open until we press a key
cv2.waitKey(0)
# close the window
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=640x486 at 0x7F5152B83C90>

# %% [markdown]
# ---

# %%
# MTCNN es una biblioteca de python (pip). Actualmente, solo se admiten Python 3.4 y versiones posteriores. 

pip install mtcnn
# Out:
# ...
#      |████████████████████████████████| 2.3MB 5.8MB/s
# ...

# %%
# Después de intalar la biblioteca, mostrará la información de mtcnn.
 pip show mtcnn
# Out:
# Name: mtcnn
# Version: 0.1.0
# Summary: Multi-task Cascaded Convolutional Neural Networks for Face Detection, based on TensorFlow
# Home-page: http://github.com/ipazc/mtcnn
# Author: Iván de Paz Centeno
# Author-email: ipazc@unileon.es
# License: MIT
# Location: /usr/local/lib/python3.7/dist-packages
# Requires: opencv-python, keras
# Required-by:

# %%
# confirmar que mtcnn se instaló correctamente
import mtcnn
# Mostrar por pantalla la versión de mtcnn
print(mtcnn.__version__)
# Out:
# 0.1.0

# %% [markdown]
# Carga la imagen, carga el modelo, hacer la detección de rostros y muestra por pantalla la lista de cada rostro detectado.

# %%
# Detección de rostros con mtcnn en una fotografía
from mtcnn.mtcnn import MTCNN
# cargar imagen desde archivo
filename = 'test1.jpg'
pixels = pyplot.imread(filename)
# crear el detector predeterminado
detector = MTCNN()
# detectar caras en la imagen
faces = detector.detect_faces(pixels)
for face in faces:
	print(face)
# Out:
# {'box': [373, 83, 100, 129], 'confidence': 0.9998095631599426, 'keypoints': {'left_eye': (392, 132), 'right_eye': (436, 139), 'nose': (403, 171), 'mouth_left': (390, 171), 'mouth_right': (438, 177)}}
# {'box': [185, 68, 90, 117], 'confidence': 0.9993304014205933, 'keypoints': {'left_eye': (208, 110), 'right_eye': (252, 119), 'nose': (220, 143), 'mouth_left': (200, 148), 'mouth_right': (245, 159)}}

# %% [markdown]
# La función draw image with boxes dibuja cuadros delimitadores detectados en el borde de la imagen.
#
# pyplot.imread: Lee una imagen de un archivo en una matriz.

# %%
# draw an image with detected objects
def draw_image_with_boxes(filename, result_list):
	# load the image
	data = pyplot.imread(filename)
	# plot the image - Traza la imagen y utilice los datos en una cuadrícula 2D normal.
	pyplot.imshow(data)
	# Obtener el contexto para dibujar el marco de la imagen
	ax = pyplot.gca()
	# definir la caja
	for result in result_list:
		# Obtener las coordenadas de la caja
		x, y, width, height = result['box']
		# crea la forma del rectagulo asignar las coordenadas y el un color
		rect = Rectangle((x, y), width, height, fill=False, color='purple')
		# Agrega el parche a los ejes de la caja 
		ax.add_patch(rect)
	# show the plot
	pyplot.show()
 
 
filename = 'test1.jpg'
# Cargar la imagem test1
pixels = pyplot.imread(filename)
# crear el detector predeterminado
detector = MTCNN()
# Detecta los rostro de la imagen test1
faces = detector.detect_faces(pixels)
# Mostrar caras en la imagen original
draw_image_with_boxes(filename, faces)
# Out:
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f5106c9def0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# ...

# %% [markdown]
# La clase matplotlib.patches.Circle se utiliza para crear un parche circular en un centro determinado xy = (x, y)con un radio determinado.

# %%
from matplotlib.patches import Circle

# draw an image with detected objects
def draw_image_with_boxes(filename, result_list):
	# load the image
	data = pyplot.imread(filename)
	# plot the image
	pyplot.imshow(data)
	# get the context for drawing boxes
	ax = pyplot.gca()
	# plot each box
	for result in result_list:
		# get coordinates
		x, y, width, height = result['box']
		# create the shape
		rect = Rectangle((x, y), width, height, fill=False, color='red')
		# draw the box
		ax.add_patch(rect)
#--------------------------------------------------------------------------------------
		# Dibujar los puntos 
		for key, value in result['keypoints'].items():
# Crea y dibuja los puntos
      #Asignar valor al radio del círculo y el color
			dot = Circle(value, radius=2, color='red')
      #Agrega el parche a los ejes de los puntos
			ax.add_patch(dot)
#--------------------------------------------------------------------------------------
	# show the plot
	pyplot.show()
 
filename = 'test1.jpg'
# load image from file
pixels = pyplot.imread(filename)
# create the detector, using default weights
detector = MTCNN()
# detect faces in the image
faces = detector.detect_faces(pixels)
# display faces on the original image
draw_image_with_boxes(filename, faces)
# Out:
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f510be9d200> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# ...

# %% [markdown]
# Detectar los rostros de la imagen test2 del equipo de natación

# %%
# draw an image with detected objects
def draw_image_with_boxes(filename, result_list):
	# load the image
	data = pyplot.imread(filename)
	# plot the image
	pyplot.imshow(data)
	# get the context for drawing boxes
	ax = pyplot.gca()
	# plot each box
	for result in result_list:
		# get coordinates
		x, y, width, height = result['box']
		# create the shape
		rect = Rectangle((x, y), width, height, fill=False, color='red')
		# draw the box
		ax.add_patch(rect)
#--------------------------------------------------------------------------------------
		# Dibujar los puntos 
		for key, value in result['keypoints'].items():
# Crea y dibuja los puntos
      #Asignar valor al radio del círculo y el color
			dot = Circle(value, radius=2, color='red')
      #Agrega el parche a los ejes de los puntos
			ax.add_patch(dot)
#--------------------------------------------------------------------------------------
	# show the plot
	pyplot.show()
 
filename = 'test2.jpg'
# load image from file
pixel2 = pyplot.imread(filename)
# create the detector, using default weights
detector = MTCNN()
# detect faces in the image
faces = detector.detect_faces(pixel2)
# display faces on the original image
draw_image_with_boxes(filename, faces)
# Out:
# WARNING:tensorflow:5 out of the last 20 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f51063eb320> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
# draw each face separately
def draw_faces(filename, result_list):
	# load the image
	data = pyplot.imread(filename)
 #--------------------------------------------------------------------------------------

	# Definir cada rostro en una subtramas
	for i in range(len(result_list)):
		# obtenga las coordenadas de cada rectangulo 
		x1, y1, width, height = result_list[i]['box']
		x2, y2 = x1 + width, y1 + height
		# define subplot
		pyplot.subplot(1, len(result_list), i+1)
		pyplot.axis('off')
		# definir el rostro
		pyplot.imshow(data[y1:y2, x1:x2])
	# show the plot
	pyplot.show()
 #--------------------------------------------------------------------------------------
filename = 'test2.jpg'
# load image from file
pixel2 = pyplot.imread(filename)
# create the detector, using default weights
detector = MTCNN()
# detect faces in the image
faces = detector.detect_faces(pixel2)
# display faces on the original image
draw_faces(filename, faces)
# Out:
# WARNING:tensorflow:5 out of the last 20 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f51096ebe60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %% [markdown]
# ## **Desarrollar una CNN para la clasificación de dígitos manuscritos del MNIST**

# %%
# Importar los datos mnist
from keras.datasets import mnist
# Cargar los conjuntos de datos 
(trainX, trainy), (testX, testy) = mnist.load_data()
# resumir el conjunto de datos cargado
print('Train: X=%s, y=%s' % (trainX.shape, trainy.shape))
print('Test: X=%s, y=%s' % (testX.shape, testy.shape))
# Define las 9 figuras principales de las imagenes.
for i in range(9):
	# define las subtramas
	pyplot.subplot(330 + 1 + i)
	# Definir datos de los píxeles de la imagen sin procesar 
	pyplot.imshow(trainX[i], cmap=pyplot.get_cmap('gray'))
#Mostrar por pantalla las 9 figuras por pantalla.
pyplot.show()
# Out:
# Train: X=(60000, 28, 28), y=(60000,)
# Test: X=(10000, 28, 28), y=(10000,)

# %%
# deeper cnn model for mnist
from numpy import mean
from numpy import std
from matplotlib import pyplot
from sklearn.model_selection import KFold
from keras.datasets import mnist
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Dense
from keras.layers import Flatten
from keras.optimizers import SGD

# load train and test dataset
def load_dataset():
	# load dataset
	(trainX, trainY), (testX, testY) = mnist.load_data()
	# reshape dataset to have a single channel
	trainX = trainX.reshape((trainX.shape[0], 28, 28, 1))
	testX = testX.reshape((testX.shape[0], 28, 28, 1))
	# one hot encode target values
	trainY = to_categorical(trainY)
	testY = to_categorical(testY)
	return trainX, trainY, testX, testY

# scale pixels
def prep_pixels(train, test):
	# convert from integers to floats
	train_norm = train.astype('float32')
	test_norm = test.astype('float32')
	# normalize to range 0-1
	train_norm = train_norm / 255.0
	test_norm = test_norm / 255.0
	# return normalized images
	return train_norm, test_norm

# define cnn model
def define_model():
	model = Sequential()
	model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', input_shape=(28, 28, 1)))
	model.add(MaxPooling2D((2, 2)))
	model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform'))
	model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform'))
	model.add(MaxPooling2D((2, 2)))
	model.add(Flatten())
	model.add(Dense(100, activation='relu', kernel_initializer='he_uniform'))
	model.add(Dense(10, activation='softmax'))
	# compile model
	opt = SGD(lr=0.01, momentum=0.9)
	model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
	return model

# evaluate a model using k-fold cross-validation
def evaluate_model(dataX, dataY, n_folds=5):
	scores, histories = list(), list()
	# prepare cross validation
	kfold = KFold(n_folds, shuffle=True, random_state=1)
	# enumerate splits
	for train_ix, test_ix in kfold.split(dataX):
		# define model
		model = define_model()
		# select rows for train and test
		trainX, trainY, testX, testY = dataX[train_ix], dataY[train_ix], dataX[test_ix], dataY[test_ix]
		# fit model
		history = model.fit(trainX, trainY, epochs=10, batch_size=32, validation_data=(testX, testY), verbose=0)
		# evaluate model
		_, acc = model.evaluate(testX, testY, verbose=0)
		print('> %.3f' % (acc * 100.0))
		# stores scores
		scores.append(acc)
		histories.append(history)
	return scores, histories

# plot diagnostic learning curves
def summarize_diagnostics(histories):
	for i in range(len(histories)):
		# plot loss
		pyplot.subplot(2, 1, 1)
		pyplot.title('Cross Entropy Loss')
		pyplot.plot(histories[i].history['loss'], color='blue', label='train')
		pyplot.plot(histories[i].history['val_loss'], color='orange', label='test')
		# plot accuracy
		pyplot.subplot(2, 1, 2)
		pyplot.title('Classification Accuracy')
		pyplot.plot(histories[i].history['accuracy'], color='blue', label='train')
		pyplot.plot(histories[i].history['val_accuracy'], color='orange', label='test')
	pyplot.show()

# summarize model performance
def summarize_performance(scores):
	# print summary
	print('Accuracy: mean=%.3f std=%.3f, n=%d' % (mean(scores)*100, std(scores)*100, len(scores)))
	# box and whisker plots of results
	pyplot.boxplot(scores)
	pyplot.show()

# run the test harness for evaluating a model
def run_test_harness():
	# load dataset
	trainX, trainY, testX, testY = load_dataset()
	# prepare pixel data
	trainX, testX = prep_pixels(trainX, testX)
	# evaluate model
	scores, histories = evaluate_model(trainX, trainY)
	# learning curves
	summarize_diagnostics(histories)
	# summarize estimated performance
	summarize_performance(scores)

# entry point, run the test harness
run_test_harness()

# %%
# deeper cnn model for mnist
from numpy import mean
from numpy import std
from matplotlib import pyplot
from sklearn.model_selection import KFold
from keras.datasets import mnist
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Dense
from keras.layers import Flatten
from keras.optimizers import SGD

# load train and test dataset
def load_dataset():
	# load dataset
	(trainX, trainY), (testX, testY) = mnist.load_data()
	# reshape dataset to have a single channel
	trainX = trainX.reshape((trainX.shape[0], 28, 28, 1))
	testX = testX.reshape((testX.shape[0], 28, 28, 1))
	# one hot encode target values
	trainY = to_categorical(trainY)
	testY = to_categorical(testY)
	return trainX, trainY, testX, testY

# scale pixels
def prep_pixels(train, test):
	# convert from integers to floats
	train_norm = train.astype('float32')
	test_norm = test.astype('float32')
	# normalize to range 0-1
	train_norm = train_norm / 255.0
	test_norm = test_norm / 255.0
	# return normalized images
	return train_norm, test_norm

# define cnn model
def define_model():
	model = Sequential()
	model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', input_shape=(28, 28, 1)))
	model.add(MaxPooling2D((2, 2)))
	model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform'))
	model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform'))
	model.add(MaxPooling2D((2, 2)))
	model.add(Flatten())
	model.add(Dense(100, activation='relu', kernel_initializer='he_uniform'))
	model.add(Dense(10, activation='softmax'))
	# compile model
	opt = SGD(lr=0.01, momentum=0.9)
	model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
	return model

# evaluate a model using k-fold cross-validation
def evaluate_model(dataX, dataY, n_folds=5):
	scores, histories = list(), list()
	# prepare cross validation
	kfold = KFold(n_folds, shuffle=True, random_state=1)
	# enumerate splits
	for train_ix, test_ix in kfold.split(dataX):
		# define model
		model = define_model()
		# select rows for train and test
		trainX, trainY, testX, testY = dataX[train_ix], dataY[train_ix], dataX[test_ix], dataY[test_ix]
		# fit model
		history = model.fit(trainX, trainY, epochs=10, batch_size=32, validation_data=(testX, testY), verbose=0)
		# evaluate model
		_, acc = model.evaluate(testX, testY, verbose=0)
		print('> %.3f' % (acc * 100.0))
		# stores scores
		scores.append(acc)
		histories.append(history)
	return scores, histories

# plot diagnostic learning curves
def summarize_diagnostics(histories):
	for i in range(len(histories)):
		# plot loss
		pyplot.subplot(2, 1, 1)
		pyplot.title('Cross Entropy Loss')
		pyplot.plot(histories[i].history['loss'], color='blue', label='train')
		pyplot.plot(histories[i].history['val_loss'], color='orange', label='test')
		# plot accuracy
		pyplot.subplot(2, 1, 2)
		pyplot.title('Classification Accuracy')
		pyplot.plot(histories[i].history['accuracy'], color='blue', label='train')
		pyplot.plot(histories[i].history['val_accuracy'], color='orange', label='test')
	pyplot.show()

# summarize model performance
def summarize_performance(scores):
	# print summary
	print('Accuracy: mean=%.3f std=%.3f, n=%d' % (mean(scores)*100, std(scores)*100, len(scores)))
	# box and whisker plots of results
	pyplot.boxplot(scores)
	pyplot.show()

# run the test harness for evaluating a model
def run_test_harness():
	# load dataset
	trainX, trainY, testX, testY = load_dataset()
	# prepare pixel data
	trainX, testX = prep_pixels(trainX, testX)
	# evaluate model
	scores, histories = evaluate_model(trainX, trainY)
	# learning curves
	summarize_diagnostics(histories)
	# summarize estimated performance
	summarize_performance(scores)

# entry point, run the test harness
run_test_harness()

# %%
# evaluate the deep model on the test dataset
from keras.datasets import mnist
from keras.models import load_model
from keras.utils import to_categorical

# load train and test dataset
def load_dataset():
	# load dataset
	(trainX, trainY), (testX, testY) = mnist.load_data()
	# reshape dataset to have a single channel
	trainX = trainX.reshape((trainX.shape[0], 28, 28, 1))
	testX = testX.reshape((testX.shape[0], 28, 28, 1))
	# one hot encode target values
	trainY = to_categorical(trainY)
	testY = to_categorical(testY)
	return trainX, trainY, testX, testY

# scale pixels
def prep_pixels(train, test):
	# convert from integers to floats
	train_norm = train.astype('float32')
	test_norm = test.astype('float32')
	# normalize to range 0-1
	train_norm = train_norm / 255.0
	test_norm = test_norm / 255.0
	# return normalized images
	return train_norm, test_norm

# run the test harness for evaluating a model
def run_test_harness():
	# load dataset
	trainX, trainY, testX, testY = load_dataset()
	# prepare pixel data
	trainX, testX = prep_pixels(trainX, testX)
	# load model
	model = load_model('final_model.h5')
	# evaluate model on test dataset
	_, acc = model.evaluate(testX, testY, verbose=0)
	print('> %.3f' % (acc * 100.0))

# entry point, run the test harness
run_test_harness()
